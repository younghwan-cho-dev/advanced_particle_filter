# %%
from run_hmc_poc import main

# %%
samples, truth = main()
# Out:
# ...
#   SVSSM + DPF + HMC  PoC  (2-asset risk contagion)
# ...
#
# [1/4] Generating synthetic data ...
#   Ground-truth Phi eigenvalues: [0.82 0.93]
#   Spectral radius: 0.9300
#   T = 75,  d = 2
#   mu_true     = [-1.   0.5]
#   Phi_true    =
# [[0.85 0.12]
#  [0.02 0.9 ]]
#   Sigma_eta_chol_true =
# [[0.15      0.       ]
#  [0.12      0.3815757]]
#
# [2/4] Building target_log_prob_fn (OT-DPF + prior) ...
#   Warm start:
#     mu0           = [-0.822  1.157]
#     Phi0          = [[0.9 0. ]
#  [0.  0.9]]
#     Sigma_eta0    = [[0.09 0.  ]
#  [0.   0.09]]
#   log_post(z0)    = -225.746
#   grad magnitude  = 27.298
#   grad all-finite = True
#   grad per-block:
#     mu:        [-1.002 -2.773]
#     Phi:       [-1.638 23.985 -6.854  2.   ]
#     Sigma_eta: [2.549 7.711 6.449]
#
# [3/4] Running HMC ...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# ...
